# %%
from PIL import Image
import numpy as np

# %%
img = Image.open('../../../my_github/MRCNN_denseCRF/dataset/images/train2014/000001_C000001-20170612174828-3201634070.jpg')
np_img = np.asarray(Image.open('../../../my_github/MRCNN_denseCRF/dataset/images/train2014/000001_C000001-20170612174828-3201634070.jpg'))

# %%
img.mode
# Out:
# 'RGB'

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x700 at 0x7F1627EDCC88>

# %%
np_img
# Out:
# array([[[ 20,  12,  27],
#         [ 32,  23,  40],
#         [ 31,  19,  41],
#         ...,
#         [125, 147, 126],
#         [127, 151, 129],
#         [131, 154, 134]],
#
#        [[ 14,  19,  22],
#         [ 35,  40,  44],
#         [ 33,  36,  43],
#         ...,
#         [129, 146, 127],
#         [130, 147, 129],
#         [133, 152, 133]],
#
#        [[171, 192, 183],
#         [168, 188, 177],
#         [173, 189, 179],
#         ...,
#         [140, 148, 133],
#         [136, 147, 131],
#         [138, 149, 133]],
#
#        ...,
#
#        [[109, 102,  56],
#         [102,  96,  44],
#         [102,  95,  40],
#         ...,
#         [148, 173, 154],
#         [146, 171, 152],
#         [146, 171, 152]],
#
#        [[107, 101,  53],
#         [101,  96,  41],
#         [101,  95,  37],
#         ...,
#         [149, 174, 155],
#         [145, 172, 153],
#         [145, 172, 153]],
#
#        [[103,  97,  47],
#         [100,  95,  39],
#         [101,  95,  35],
# ...

# %%
np_img.astype(np.int32)
# Out:
# array([[[ 20,  12,  27],
#         [ 32,  23,  40],
#         [ 31,  19,  41],
#         ...,
#         [125, 147, 126],
#         [127, 151, 129],
#         [131, 154, 134]],
#
#        [[ 14,  19,  22],
#         [ 35,  40,  44],
#         [ 33,  36,  43],
#         ...,
#         [129, 146, 127],
#         [130, 147, 129],
#         [133, 152, 133]],
#
#        [[171, 192, 183],
#         [168, 188, 177],
#         [173, 189, 179],
#         ...,
#         [140, 148, 133],
#         [136, 147, 131],
#         [138, 149, 133]],
#
#        ...,
#
#        [[109, 102,  56],
#         [102,  96,  44],
#         [102,  95,  40],
#         ...,
#         [148, 173, 154],
#         [146, 171, 152],
#         [146, 171, 152]],
#
#        [[107, 101,  53],
#         [101,  96,  41],
#         [101,  95,  37],
#         ...,
#         [149, 174, 155],
#         [145, 172, 153],
#         [145, 172, 153]],
#
#        [[103,  97,  47],
#         [100,  95,  39],
#         [101,  95,  35],
# ...

# %%
np_img.dtype
# Out:
# dtype('uint8')

# %%
Image.fromarray(np_img.astype(np.float32).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x700 at 0x7F1627EFCAC8>
